# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data1 = pd.read_csv('output_1000.csv', header=None).values
data2 = pd.read_csv('output_10000.csv', header=None).values
data3 = pd.read_csv('output_100000.csv', header=None).values
data4 = pd.read_csv('output_1000000.csv', header=None).values

# %%
data1 = pd.read_csv('output_normal.csv', header=None).values
data2 = pd.read_csv('output_mp.csv', header=None).values

# %%
plt.plot(data1[0])
plt.plot(data2[0])
plt.show()
